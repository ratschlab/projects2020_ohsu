# %%
import os 
from pathlib import Path
import pandas as pd
from collections import defaultdict
import glob
import timeit
import argparse
import numpy as np

# %%
def reader_FDR_results(search_out_folder):
    search_res = dict()
    for path in glob.glob(os.path.join(search_out_folder, 'assign-confidence.target.txt')): 
        sample = path.split('/')[-3]
        search_res[sample] = path 
    return search_res


def reader_experiments(list_experiments):
    '''Read files with path lists'''
    with open(list_experiments, 'r') as f:
        path_dict = {}
        for i in f.readlines():
            sample_name = os.path.basename(i.strip()).split('_')[1]
            sample_short = '-'.join(sample_name.split('-')[0:3])
            path_dict[sample_short] = i.strip()
    return path_dict


def experiments_maps(path):
    '''Extract experiment maps'''
    df = pd.read_csv(path, sep = '\t')
    id_to_pep = {}
    id_to_exp = {}
    exp_to_id = defaultdict(list)
    for i, row in df.iterrows():
        id_to_pep[row['peptide_id']] = row['peptide_sequence']
        id_to_exp[row['peptide_id']] = row['experiment_ids'].split(';')

    for k, v in id_to_exp.items():
        for ID in v:
            exp_to_id[ID].append(k)
    return id_to_pep, id_to_exp, exp_to_id


def search_result_rows(df_search):
    id_to_row = defaultdict(list)
    for i, idx in enumerate(df_search['protein id']):
        if idx is np.nan:
            print('ERROR: Search not successful on all fractions of sample. Please RERUN')
        for name_ in idx.split(','):
            if 'pepID' not in name_:
                continue
            pep_ix = int(name_.split('-')[1].replace('(1)', ''))
            id_to_row[pep_ix].append(i)
    return id_to_row


def select_search_result(id_to_exp, id_to_SearchRow):
    select_rows = defaultdict(set)
    for pep_idx, exp_list in id_to_exp.items():
        for experiment in exp_list:
            peptide_rows = id_to_SearchRow[pep_idx]
            if peptide_rows:
                select_rows[experiment].update(peptide_rows)
    return select_rows


def reconstruct_experiment_FDR(select_rows_pipeline, df_search, save_folder, sample, create_sample_subfolder=True):
    '''Selects all the rows from the initial experiment
    Save'''
    df_search_i = df_search.reset_index()
    for experiment_id in select_rows_pipeline:
        print(f'.....{experiment_id}')

        df_experiment = df_search_i.loc[select_rows_pipeline[experiment_id]]
        df_experiment = df_experiment.drop_duplicates()
        

        if create_sample_subfolder:
            path_save = os.path.join(save_folder, sample, 'assign_conf_pooled_FDR') 
        else:
            path_save = os.path.join(save_folder)

        Path(path_save).mkdir(parents=True, exist_ok=True)
        path_save = os.path.join(path_save, f'tsearch-{experiment_id}.txt')
        print(path_save)
        df_experiment.to_csv(path_save, sep = '\t', index=None)

# %%
list_experiments = '/cluster/work/grlab/projects/projects2020_OHSU/share_OHUS_PNLL/OHSU_Oct2023_data/OHSU_experiments_per_peptides_list.txt'
# list_experiments_eth = '/cluster/work/grlab/projects/projects2020_OHSU/share_OHUS_PNLL/ETH_Oct2023_data/ETH_experiments_per_peptides_list.txt'
# eth_or_ohsu = 'joint_search' #which experimet file to use
search_out_folder = '/cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/*/tide_search'

save_folder = '/cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU'
create_sample_subfolder = True
rerank_psm = False

# %%
exp_all = reader_experiments(list_experiments)
FDR_res = reader_FDR_results(search_out_folder)

n_samples_process = 1
for sample, FDR_file in FDR_res.items():
    print(sample)
    n_samples_process -= 1
    print(n_samples_process)

    print('...read FDR result')
    df_FDR = pd.read_csv(FDR_file, sep = '\t')
    print(df_FDR.shape)

    print('...extract rows IDS corresponding to peptides')
    id_to_SearchRow = search_result_rows(df_FDR)
    print(len(id_to_SearchRow))

    print('...process experiment map')
    id_to_pep, id_to_exp, exp_to_id = experiments_maps(exp_all[sample])
    print(len(id_to_exp))

    print('...select experiment rows')
    select_rows = select_search_result(id_to_exp, id_to_SearchRow)
    print(len(select_rows))

    print('...save experiments')
    reconstruct_experiment_FDR(select_rows, df_FDR, save_folder, sample, create_sample_subfolder=create_sample_subfolder)


    if n_samples_process < 1:
        break
# Out:
# TCGA-25-1319
# 0
# ...read FDR result
# (173901, 17)
# ...extract rows IDS corresponding to peptides
# 49475
# ...process experiment map
# 145419
# ...select experiment rows
# 180
# ...save experiments
# .....J0AN01PC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0AN01PC.txt
# .....J0AN12PC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0AN12PC.txt
# .....J0AN32PC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0AN32PC.txt
# .....J0ANA2PC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0ANA2PC.txt
# .....J0AN1XPC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0AN1XPC.txt
# .....J0AN3XPC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0AN3XPC.txt
# .....J0ANAXPC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0ANAXPC.txt
# .....J0AN1APC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0AN1APC.txt
# .....J0AN3APC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0AN3APC.txt
# .....J0A101PC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A101PC.txt
# .....J0A112PC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A112PC.txt
# .....J0A132PC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A132PC.txt
# .....J0A1A2PC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A1A2PC.txt
# .....J0A11XPC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A11XPC.txt
# .....J0A13XPC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A13XPC.txt
# .....J0A1AXPC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A1AXPC.txt
# .....J0A11APC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A11APC.txt
# .....J0A13APC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A13APC.txt
# .....J02101PC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J02101PC.txt
# .....J02112PC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J02112PC.txt
# .....J02132PC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J02132PC.txt
# .....J021A2PC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J021A2PC.txt
# .....J0211XPC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0211XPC.txt
# .....J0213XPC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0213XPC.txt
# .....J021AXPC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J021AXPC.txt
# .....J0211APC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0211APC.txt
# .....J0213APC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0213APC.txt
# .....J0A501PC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A501PC.txt
# .....J0A512PC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A512PC.txt
# .....J0A532PC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A532PC.txt
# .....J0A5A2PC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A5A2PC.txt
# .....J0A51XPC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A51XPC.txt
# .....J0A53XPC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A53XPC.txt
# .....J0A5AXPC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A5AXPC.txt
# .....J0A51APC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A51APC.txt
# .....J0A53APC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A53APC.txt
# .....J02501PC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J02501PC.txt
# .....J02512PC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J02512PC.txt
# .....J02532PC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J02532PC.txt
# .....J025A2PC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J025A2PC.txt
# .....J0251XPC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0251XPC.txt
# .....J0253XPC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0253XPC.txt
# .....J025AXPC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J025AXPC.txt
# .....J0251APC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0251APC.txt
# .....J0253APC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0253APC.txt
# .....J0AN01PA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0AN01PA.txt
# .....J0AN12PA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0AN12PA.txt
# .....J0AN32PA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0AN32PA.txt
# .....J0ANA2PA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0ANA2PA.txt
# .....J0AN1XPA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0AN1XPA.txt
# .....J0AN3XPA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0AN3XPA.txt
# .....J0ANAXPA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0ANAXPA.txt
# .....J0AN1APA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0AN1APA.txt
# .....J0AN3APA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0AN3APA.txt
# .....J0A101PA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A101PA.txt
# .....J0A112PA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A112PA.txt
# .....J0A132PA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A132PA.txt
# .....J0A1A2PA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A1A2PA.txt
# .....J0A11XPA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A11XPA.txt
# .....J0A13XPA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A13XPA.txt
# .....J0A1AXPA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A1AXPA.txt
# .....J0A11APA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A11APA.txt
# .....J0A13APA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A13APA.txt
# .....J02101PA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J02101PA.txt
# .....J02112PA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J02112PA.txt
# .....J02132PA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J02132PA.txt
# .....J021A2PA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J021A2PA.txt
# .....J0211XPA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0211XPA.txt
# .....J0213XPA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0213XPA.txt
# .....J021AXPA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J021AXPA.txt
# .....J0211APA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0211APA.txt
# .....J0213APA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0213APA.txt
# .....J0A501PA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A501PA.txt
# .....J0A512PA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A512PA.txt
# .....J0A532PA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A532PA.txt
# .....J0A5A2PA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A5A2PA.txt
# .....J0A51XPA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A51XPA.txt
# .....J0A53XPA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A53XPA.txt
# .....J0A5AXPA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A5AXPA.txt
# .....J0A51APA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A51APA.txt
# .....J0A53APA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A53APA.txt
# .....J02501PA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J02501PA.txt
# .....J02512PA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J02512PA.txt
# .....J02532PA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J02532PA.txt
# .....J025A2PA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J025A2PA.txt
# .....J0251XPA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0251XPA.txt
# .....J0253XPA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0253XPA.txt
# .....J025AXPA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J025AXPA.txt
# .....J0251APA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0251APA.txt
# .....J0253APA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0253APA.txt
# .....J0AN3XGC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0AN3XGC.txt
# .....J0ANAXGC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0ANAXGC.txt
# .....J0AN3AGC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0AN3AGC.txt
# .....J0A13XGC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A13XGC.txt
# .....J0A1AXGC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A1AXGC.txt
# .....J0A13AGC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A13AGC.txt
# .....J0AN3XGA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0AN3XGA.txt
# .....J0ANAXGA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0ANAXGA.txt
# .....J0AN3AGA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0AN3AGA.txt
# .....J0A13XGA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A13XGA.txt
# .....J0A1AXGA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A1AXGA.txt
# .....J0A13AGA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A13AGA.txt
# .....J021AXGC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J021AXGC.txt
# .....J0A5AXGC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A5AXGC.txt
# .....J025AXGC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J025AXGC.txt
# .....J021AXGA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J021AXGA.txt
# .....J0A5AXGA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A5AXGA.txt
# .....J025AXGA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J025AXGA.txt
# .....J0A53AGC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A53AGC.txt
# .....J0A53AGA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A53AGA.txt
# .....J0AN01GC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0AN01GC.txt
# .....J0AN12GC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0AN12GC.txt
# .....J0AN32GC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0AN32GC.txt
# .....J0ANA2GC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0ANA2GC.txt
# .....J0AN1XGC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0AN1XGC.txt
# .....J0AN1AGC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0AN1AGC.txt
# .....J0A101GC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A101GC.txt
# .....J0A112GC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A112GC.txt
# .....J0A132GC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A132GC.txt
# .....J0A1A2GC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A1A2GC.txt
# .....J0A11XGC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A11XGC.txt
# .....J0A11AGC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A11AGC.txt
# .....J02101GC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J02101GC.txt
# .....J02112GC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J02112GC.txt
# .....J02132GC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J02132GC.txt
# .....J021A2GC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J021A2GC.txt
# .....J0211XGC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0211XGC.txt
# .....J0213XGC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0213XGC.txt
# .....J0211AGC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0211AGC.txt
# .....J0213AGC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0213AGC.txt
# .....J0AN01GA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0AN01GA.txt
# .....J0AN12GA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0AN12GA.txt
# .....J0AN32GA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0AN32GA.txt
# .....J0ANA2GA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0ANA2GA.txt
# .....J0AN1XGA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0AN1XGA.txt
# .....J0AN1AGA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0AN1AGA.txt
# .....J0A101GA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A101GA.txt
# .....J0A112GA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A112GA.txt
# .....J0A132GA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A132GA.txt
# .....J0A1A2GA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A1A2GA.txt
# .....J0A11XGA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A11XGA.txt
# .....J0A11AGA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A11AGA.txt
# .....J02101GA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J02101GA.txt
# .....J02112GA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J02112GA.txt
# .....J02132GA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J02132GA.txt
# .....J021A2GA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J021A2GA.txt
# .....J0211XGA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0211XGA.txt
# .....J0213XGA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0213XGA.txt
# .....J0211AGA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0211AGA.txt
# .....J0213AGA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0213AGA.txt
# .....J0A5A2GC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A5A2GC.txt
# .....J025A2GC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J025A2GC.txt
# .....J0A5A2GA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A5A2GA.txt
# .....J025A2GA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J025A2GA.txt
# .....J0A501GC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A501GC.txt
# .....J0A512GC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A512GC.txt
# .....J0A532GC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A532GC.txt
# .....J0A51XGC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A51XGC.txt
# .....J0A53XGC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A53XGC.txt
# .....J0A51AGC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A51AGC.txt
# .....J0A501GA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A501GA.txt
# .....J0A512GA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A512GA.txt
# .....J0A532GA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A532GA.txt
# .....J0A51XGA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A51XGA.txt
# .....J0A53XGA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A53XGA.txt
# .....J0A51AGA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0A51AGA.txt
# .....J02532GC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J02532GC.txt
# .....J0253XGC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0253XGC.txt
# .....J0253AGC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0253AGC.txt
# .....J02532GA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J02532GA.txt
# .....J0253XGA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0253XGA.txt
# .....J0253AGA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0253AGA.txt
# .....J02501GC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J02501GC.txt
# .....J02512GC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J02512GC.txt
# .....J0251XGC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0251XGC.txt
# .....J0251AGC
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0251AGC.txt
# .....J02501GA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J02501GA.txt
# .....J02512GA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J02512GA.txt
# .....J0251XGA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0251XGA.txt
# .....J0251AGA
# /cluster/work/grlab/projects/projects2020_OHSU/proteomics/OHSU/TCGA-25-1319/assign_conf_pooled_FDR/tsearch-J0251AGA.txt

# %% [markdown]
# # TEST

# %%
idx_list = set()
for name_ in split_exp['protein id']:
    for single in name_.split(','):
        if 'pepID' in  single:
            idx_list.add(int(single.split('-')[1].replace('(1)', '')))
            

foo = pd.read_csv('/cluster/work/grlab/projects/projects2020_OHSU/tmp_file', header = None)

full_exp = set(foo[0])


len(full_exp.difference(idx_list))

len(idx_list.difference(full_exp))
