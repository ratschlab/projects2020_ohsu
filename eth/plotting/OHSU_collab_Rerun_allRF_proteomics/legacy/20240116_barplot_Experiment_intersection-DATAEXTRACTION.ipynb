# %%
import pandas as pd
import glob
import os 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from collections import defaultdict
# %load_ext autoreload
# %autoreload 2
#from ..helpers_barplot_intersection import reader_assign_conf_pep, plot_text, plot_intersection_bars
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def reader_assign_conf_pep(path, FDR_threshold, col_seq, col_qval, input_trypPep):
    print(f'Reading {path}')
    if os.path.isfile(path):
        # Read
        df = pd.read_csv(path, sep = '\t')
        df_all_pep = pd.read_csv(input_trypPep, sep = '\t')
        
        # Total
        tot_peptides = len(df_all_pep['sequence'].unique())
        
        print(f'Shape of FDR file: {df.shape[0]}')
        print(f'Total input tryptic junction peptides: {tot_peptides}')
        assert('sequence' in df.columns)
        
        # Validated peptides
        df_filtered = df.loc[df[col_qval] < FDR_threshold]
        peptides = set(df_filtered[col_seq])
        val = len(peptides)

        # Validation rate
        if tot_peptides:
            val_rate = np.round(val / tot_peptides * 100 , 2)
        else:
            val_rate = 0.0
        
        print(f'Number of validated unique peptides: {val}')
        print(f'Validation Rate: {val_rate } percent')
        
        return val, val_rate, peptides, df_filtered, tot_peptides
    else:
        return 0, 0.0, set(), None, None

# %%
# INPUTS 
read_from_disk = True # or reload
proteomicsdir = '/cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024'
#proteomicsdir = '/cluster/work/grlab/projects/projects2020_OHSU/proteomics'

pipelines = ['OHSU', 'ETH']

FDR_limit = 0.05
MS_FDR = '_crux' #choices: '_crema' '_crux' or ''
MS_strategy = 'pool' #Choices: 'pool' 'joint', 'single' 

#pool: pool all experiments per pipeline
#joint: pool all experiments for both pipeline
#single: per experiment per pipeline

if MS_FDR == '_crema':
    FDR_file = 'crema.peptides.txt'
    col_seq = 'sequence'
    col_qvalue = 'crema q-value'
elif MS_FDR == '_crux' or  MS_FDR == '':
    FDR_file = 'assign-confidence.target.txt'
    col_seq = 'unmodified sequence'
    col_qvalue = 'tdc q-value'
else:
    print(f'ERROR: wrong input for {FDR_file}')

    

sample_plot_dir = {}
run_type_plot_dir = {}    
all_samples = []

# BRCA
samples = ['TCGA-C8-A12P-01A-11R-A115-07',
                  'TCGA-AO-A0JM-01A-21R-A056-07',
                  'TCGA-BH-A18V-01A-11R-A12D-07',
                  'TCGA-A2-A0D2-01A-21R-A034-07',
                  'TCGA-A2-A0SX-01A-12R-A084-07']
all_samples.extend(samples)
basedir = '/cluster/work/grlab/projects/projects2020_OHSU/peptides_generation/CANCER_eth/commit_c4dd02c_conf2_Frame_cap0_runs/TCGA_Breast_1102'
filter_dir = os.path.join(basedir, 'filtering_samples', 'filters_19May_order_5ge_wAnnot_GPstar')

for sample in samples:
    sample_plot_dir[sample] = os.path.join(filter_dir, 'plots')
    run_type_plot_dir[sample] = 'BRCA'
    
# OV
samples = ['TCGA-25-1319-01A-01R-1565-13',
                  'TCGA-25-1313-01A-01R-1565-13',
                  'TCGA-61-2008-01A-02R-1568-13',
                  'TCGA-24-1431-01A-01R-1566-13',
                  'TCGA-24-2298-01A-01R-1569-13']
all_samples.extend(samples)
basedir = '/cluster/work/grlab/projects/projects2020_OHSU/peptides_generation/CANCER_eth/commit_c4dd02c_conf2_Frame_cap0_runs/TCGA_Ovarian_374'
filter_dir = os.path.join(basedir, 'filtering_samples', 'filters_19May_order_5ge_wAnnot_GPstar')

for sample in samples:
    sample_plot_dir[sample] = os.path.join(filter_dir, 'plots')
    run_type_plot_dir[sample] = 'OV'
    
    
    
# PLOTTING Parameters 
ticks_fontsize = 12
axislabels_fontsize = 12
legend_fontsize = 12
axes_fontsize = 15
save = True
sample = None

# %% [markdown]
# # Parse: results for all experiments

# %%
## Get peptides
if read_from_disk:
    samples_store_pep = {}
    samples_store_rates = {}
    samples_store_total = {}
#     experiment_pipelines_peptides =  
#     experiments_pipelines_rates = defaultdict(dict)


    for sample in all_samples:

        sample_short = '-'.join(sample.split('-')[0:3])
        samples_store_pep[sample] = defaultdict(dict)
        samples_store_rates[sample] = defaultdict(dict)
        samples_store_total[sample] = defaultdict(dict)
        for pipeline in pipelines:
            path_single = os.path.join(proteomicsdir, pipeline, sample_short, 
                                       f'assign_conf_per_experiment{MS_FDR}')
            path_pool_pipeline = os.path.join(proteomicsdir, pipeline, sample_short, 
                                              f'assign_conf_pooled_FDR{MS_FDR}')
            path_pool_union = os.path.join(proteomicsdir, 
                                           f'assign_conf_joint_to_{pipeline}{MS_FDR}', sample_short)
            path_TEST_OHSU = os.path.join(proteomicsdir, 'OHSU', sample_short, 
                                       f'assign_conf_per_experiment{MS_FDR}')
            path_TEST_ETH = os.path.join(proteomicsdir, 'ETH', sample_short, 
                                       f'assign_conf_per_experiment{MS_FDR}')
            base_input_trypPep = os.path.join(proteomicsdir, pipeline, sample_short, 
                                             'trypsine_digest_per_experiment')


            experiment_list = [ i.split('/')[-1] for i in glob.glob(path_single + '/*')] #check

            for experiment in experiment_list:
                if pipeline == 'OHSU':
                    original_name = experiment
                    cut_name = experiment[1:]
                else:
                    original_name = experiment
                    cut_name = experiment          

                if os.path.isfile(os.path.join(path_TEST_OHSU, 'J' + cut_name, FDR_file)) and \
                     os.path.isfile(os.path.join(path_TEST_ETH, cut_name, FDR_file)): #Commun experiments               

                    # search 1 experiment, 1 pipeline  
                    if MS_strategy == 'single':
                        df = os.path.join(path_single, original_name, FDR_file)
                    # search all experiments, 1 pipeline
                    if MS_strategy == 'pool':
                        df = os.path.join(path_pool_pipeline, f'tsearch-{original_name}.txt')
                    # search all experiments, 1 union of pipelines
                    if MS_strategy == 'joint':
                        df = os.path.join(path_pool_union, f'tsearch-{original_name}.txt')
                    
                    input_trypPep = os.path.join(base_input_trypPep, f'tsearch-{original_name}.txt')
                    
                    val, val_rate, peptides, _, tot = reader_assign_conf_pep(df, FDR_limit, col_seq, col_qvalue, input_trypPep)
                    samples_store_pep[sample][cut_name][pipeline] = peptides
                    samples_store_rates[sample][cut_name][pipeline] = val_rate
                    samples_store_total[sample][cut_name][pipeline] = tot

                    print('\n')
# Out:
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-J0A53XGA.txt
# Shape of FDR file: 1469
# Total input tryptic junction peptides: 33
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-J0A13AGA.txt
# Shape of FDR file: 9545
# Total input tryptic junction peptides: 273
# Number of validated unique peptides: 4
# Validation Rate: 1.47 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-J0A51XGA.txt
# Shape of FDR file: 389
# Total input tryptic junction peptides: 12
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-J0213XGA.txt
# Shape of FDR file: 1511
# Total input tryptic junction peptides: 43
# Number of validated unique peptides: 1
# Validation Rate: 2.33 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-J0AN01GA.txt
# Shape of FDR file: 28017
# Total input tryptic junction peptides: 802
# Number of validated unique peptides: 6
# Validation Rate: 0.75 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-J0A532GA.txt
# Shape of FDR file: 664
# Total input tryptic junction peptides: 20
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-J0A11XGA.txt
# Shape of FDR file: 2917
# Total input tryptic junction peptides: 64
# Number of validated unique peptides: 1
# Validation Rate: 1.56 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-J0253XGA.txt
# Shape of FDR file: 376
# Total input tryptic junction peptides: 8
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-J0251XGA.txt
# Shape of FDR file: 15
# Total input tryptic junction peptides: 2
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-J0AN3AGA.txt
# Shape of FDR file: 43651
# Total input tryptic junction peptides: 1274
# Number of validated unique peptides: 10
# Validation Rate: 0.78 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-J0A51AGA.txt
# Shape of FDR file: 389
# Total input tryptic junction peptides: 12
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-J0AN12GA.txt
# Shape of FDR file: 28548
# Total input tryptic junction peptides: 817
# Number of validated unique peptides: 6
# Validation Rate: 0.73 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-J0A11AGA.txt
# Shape of FDR file: 2917
# Total input tryptic junction peptides: 64
# Number of validated unique peptides: 1
# Validation Rate: 1.56 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-J0A101GA.txt
# Shape of FDR file: 2762
# Total input tryptic junction peptides: 62
# Number of validated unique peptides: 1
# Validation Rate: 1.61 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-J0A501GA.txt
# Shape of FDR file: 389
# Total input tryptic junction peptides: 12
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-J0211AGA.txt
# Shape of FDR file: 712
# Total input tryptic junction peptides: 17
# Number of validated unique peptides: 1
# Validation Rate: 5.88 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-J02512GA.txt
# Shape of FDR file: 15
# Total input tryptic junction peptides: 2
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-J0AN32GA.txt
# Shape of FDR file: 33872
# Total input tryptic junction peptides: 979
# Number of validated unique peptides: 8
# Validation Rate: 0.82 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-J0A512GA.txt
# Shape of FDR file: 389
# Total input tryptic junction peptides: 12
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-J0A112GA.txt
# Shape of FDR file: 2917
# Total input tryptic junction peptides: 64
# Number of validated unique peptides: 1
# Validation Rate: 1.56 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-J0AN1AGA.txt
# Shape of FDR file: 28548
# Total input tryptic junction peptides: 817
# Number of validated unique peptides: 6
# Validation Rate: 0.73 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-J02532GA.txt
# Shape of FDR file: 130
# Total input tryptic junction peptides: 5
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-J0A13XGA.txt
# Shape of FDR file: 8548
# Total input tryptic junction peptides: 228
# Number of validated unique peptides: 3
# Validation Rate: 1.32 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-J0253AGA.txt
# Shape of FDR file: 390
# Total input tryptic junction peptides: 9
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-J0251AGA.txt
# Shape of FDR file: 15
# Total input tryptic junction peptides: 2
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-J02501GA.txt
# Shape of FDR file: 15
# Total input tryptic junction peptides: 2
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-J0A132GA.txt
# Shape of FDR file: 4581
# Total input tryptic junction peptides: 119
# Number of validated unique peptides: 2
# Validation Rate: 1.68 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-J0A53AGA.txt
# Shape of FDR file: 1816
# Total input tryptic junction peptides: 49
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-J02101GA.txt
# Shape of FDR file: 712
# Total input tryptic junction peptides: 17
# Number of validated unique peptides: 1
# Validation Rate: 5.88 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-J02112GA.txt
# Shape of FDR file: 712
# Total input tryptic junction peptides: 17
# Number of validated unique peptides: 1
# Validation Rate: 5.88 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-J0213AGA.txt
# Shape of FDR file: 1819
# Total input tryptic junction peptides: 57
# Number of validated unique peptides: 1
# Validation Rate: 1.75 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-J0AN3XGA.txt
# Shape of FDR file: 42540
# Total input tryptic junction peptides: 1220
# Number of validated unique peptides: 9
# Validation Rate: 0.74 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-J02132GA.txt
# Shape of FDR file: 1021
# Total input tryptic junction peptides: 28
# Number of validated unique peptides: 1
# Validation Rate: 3.57 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-J0211XGA.txt
# Shape of FDR file: 712
# Total input tryptic junction peptides: 17
# Number of validated unique peptides: 1
# Validation Rate: 5.88 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-J0AN1XGA.txt
# Shape of FDR file: 28548
# Total input tryptic junction peptides: 817
# Number of validated unique peptides: 6
# Validation Rate: 0.73 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-0211AGA.txt
# Shape of FDR file: 626
# Total input tryptic junction peptides: 10
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-0211XGA.txt
# Shape of FDR file: 626
# Total input tryptic junction peptides: 10
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-02532GA.txt
# Shape of FDR file: 362
# Total input tryptic junction peptides: 6
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-0A101GA.txt
# Shape of FDR file: 520
# Total input tryptic junction peptides: 9
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-0A512GA.txt
# Shape of FDR file: 116
# Total input tryptic junction peptides: 4
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-0AN1AGA.txt
# Shape of FDR file: 1426
# Total input tryptic junction peptides: 15
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-0A13AGA.txt
# Shape of FDR file: 2645
# Total input tryptic junction peptides: 38
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-0213XGA.txt
# Shape of FDR file: 1703
# Total input tryptic junction peptides: 28
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-0A501GA.txt
# Shape of FDR file: 116
# Total input tryptic junction peptides: 4
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-0A11AGA.txt
# Shape of FDR file: 626
# Total input tryptic junction peptides: 10
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-0AN01GA.txt
# Shape of FDR file: 1313
# Total input tryptic junction peptides: 13
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-0AN1XGA.txt
# Shape of FDR file: 1426
# Total input tryptic junction peptides: 15
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-0AN32GA.txt
# Shape of FDR file: 2147
# Total input tryptic junction peptides: 22
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-02101GA.txt
# Shape of FDR file: 520
# Total input tryptic junction peptides: 9
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-0A11XGA.txt
# Shape of FDR file: 626
# Total input tryptic junction peptides: 10
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-02132GA.txt
# Shape of FDR file: 1158
# Total input tryptic junction peptides: 17
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-0251XGA.txt
# Shape of FDR file: 20
# Total input tryptic junction peptides: 2
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-0253AGA.txt
# Shape of FDR file: 974
# Total input tryptic junction peptides: 9
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-0253XGA.txt
# Shape of FDR file: 453
# Total input tryptic junction peptides: 8
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-0A132GA.txt
# Shape of FDR file: 1158
# Total input tryptic junction peptides: 17
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-0213AGA.txt
# Shape of FDR file: 2465
# Total input tryptic junction peptides: 35
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-0A13XGA.txt
# Shape of FDR file: 1879
# Total input tryptic junction peptides: 30
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-0A53AGA.txt
# Shape of FDR file: 1591
# Total input tryptic junction peptides: 20
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-0AN12GA.txt
# Shape of FDR file: 1419
# Total input tryptic junction peptides: 14
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-0AN3AGA.txt
# Shape of FDR file: 3328
# Total input tryptic junction peptides: 46
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-0A51XGA.txt
# Shape of FDR file: 116
# Total input tryptic junction peptides: 4
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-02501GA.txt
# Shape of FDR file: 20
# Total input tryptic junction peptides: 2
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-0AN3XGA.txt
# Shape of FDR file: 3083
# Total input tryptic junction peptides: 39
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-0A532GA.txt
# Shape of FDR file: 584
# Total input tryptic junction peptides: 9
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-0A112GA.txt
# Shape of FDR file: 626
# Total input tryptic junction peptides: 10
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-0A53XGA.txt
# Shape of FDR file: 825
# Total input tryptic junction peptides: 12
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-0251AGA.txt
# Shape of FDR file: 20
# Total input tryptic junction peptides: 2
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-0A51AGA.txt
# Shape of FDR file: 116
# Total input tryptic junction peptides: 4
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-02512GA.txt
# Shape of FDR file: 20
# Total input tryptic junction peptides: 2
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-C8-A12P/assign_conf_pooled_FDR_crux/tsearch-02112GA.txt
# Shape of FDR file: 626
# Total input tryptic junction peptides: 10
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-J0A53XGA.txt
# Shape of FDR file: 700
# Total input tryptic junction peptides: 21
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-J0A13AGA.txt
# Shape of FDR file: 5107
# Total input tryptic junction peptides: 118
# Number of validated unique peptides: 3
# Validation Rate: 2.54 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-J0213XGA.txt
# Shape of FDR file: 1163
# Total input tryptic junction peptides: 32
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-J0AN01GA.txt
# Shape of FDR file: 17357
# Total input tryptic junction peptides: 414
# Number of validated unique peptides: 6
# Validation Rate: 1.45 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-J0A532GA.txt
# Shape of FDR file: 108
# Total input tryptic junction peptides: 5
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-J0A11XGA.txt
# Shape of FDR file: 1194
# Total input tryptic junction peptides: 21
# Number of validated unique peptides: 1
# Validation Rate: 4.76 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-J0253XGA.txt
# Shape of FDR file: 228
# Total input tryptic junction peptides: 10
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-J0AN3AGA.txt
# Shape of FDR file: 25372
# Total input tryptic junction peptides: 616
# Number of validated unique peptides: 9
# Validation Rate: 1.46 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-J0AN12GA.txt
# Shape of FDR file: 17581
# Total input tryptic junction peptides: 422
# Number of validated unique peptides: 6
# Validation Rate: 1.42 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-J0A11AGA.txt
# Shape of FDR file: 1194
# Total input tryptic junction peptides: 21
# Number of validated unique peptides: 1
# Validation Rate: 4.76 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-J0A101GA.txt
# Shape of FDR file: 1057
# Total input tryptic junction peptides: 20
# Number of validated unique peptides: 1
# Validation Rate: 5.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-J0211AGA.txt
# Shape of FDR file: 231
# Total input tryptic junction peptides: 4
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-J0AN32GA.txt
# Shape of FDR file: 19915
# Total input tryptic junction peptides: 486
# Number of validated unique peptides: 7
# Validation Rate: 1.44 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-J0A112GA.txt
# Shape of FDR file: 1194
# Total input tryptic junction peptides: 21
# Number of validated unique peptides: 1
# Validation Rate: 4.76 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-J0AN1AGA.txt
# Shape of FDR file: 17581
# Total input tryptic junction peptides: 422
# Number of validated unique peptides: 6
# Validation Rate: 1.42 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-J02532GA.txt
# Shape of FDR file: 108
# Total input tryptic junction peptides: 4
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-J0A13XGA.txt
# Shape of FDR file: 4277
# Total input tryptic junction peptides: 93
# Number of validated unique peptides: 3
# Validation Rate: 3.23 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-J0253AGA.txt
# Shape of FDR file: 383
# Total input tryptic junction peptides: 15
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-J0A132GA.txt
# Shape of FDR file: 1576
# Total input tryptic junction peptides: 36
# Number of validated unique peptides: 1
# Validation Rate: 2.78 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-J0A53AGA.txt
# Shape of FDR file: 1339
# Total input tryptic junction peptides: 36
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-J02101GA.txt
# Shape of FDR file: 231
# Total input tryptic junction peptides: 4
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-J02112GA.txt
# Shape of FDR file: 231
# Total input tryptic junction peptides: 4
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-J0213AGA.txt
# Shape of FDR file: 1815
# Total input tryptic junction peptides: 49
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-J0AN3XGA.txt
# Shape of FDR file: 24542
# Total input tryptic junction peptides: 590
# Number of validated unique peptides: 9
# Validation Rate: 1.53 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-J02132GA.txt
# Shape of FDR file: 339
# Total input tryptic junction peptides: 9
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-J0211XGA.txt
# Shape of FDR file: 231
# Total input tryptic junction peptides: 4
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-J0AN1XGA.txt
# Shape of FDR file: 17581
# Total input tryptic junction peptides: 422
# Number of validated unique peptides: 6
# Validation Rate: 1.42 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-0211AGA.txt
# Shape of FDR file: 1
# Total input tryptic junction peptides: 1
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-0211XGA.txt
# Shape of FDR file: 1
# Total input tryptic junction peptides: 1
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-02532GA.txt
# Shape of FDR file: 10
# Total input tryptic junction peptides: 2
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-0A101GA.txt
# Shape of FDR file: 1
# Total input tryptic junction peptides: 1
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-0AN1AGA.txt
# Shape of FDR file: 1875
# Total input tryptic junction peptides: 33
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-0A13AGA.txt
# Shape of FDR file: 1477
# Total input tryptic junction peptides: 28
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-0213XGA.txt
# Shape of FDR file: 500
# Total input tryptic junction peptides: 15
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-0A11AGA.txt
# Shape of FDR file: 1
# Total input tryptic junction peptides: 1
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-0AN01GA.txt
# Shape of FDR file: 1800
# Total input tryptic junction peptides: 32
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-0AN1XGA.txt
# Shape of FDR file: 1875
# Total input tryptic junction peptides: 33
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-0AN32GA.txt
# Shape of FDR file: 2342
# Total input tryptic junction peptides: 45
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-02101GA.txt
# Shape of FDR file: 1
# Total input tryptic junction peptides: 1
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-0A11XGA.txt
# Shape of FDR file: 1
# Total input tryptic junction peptides: 1
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-02132GA.txt
# Shape of FDR file: 28
# Total input tryptic junction peptides: 4
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-0253AGA.txt
# Shape of FDR file: 91
# Total input tryptic junction peptides: 5
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-0253XGA.txt
# Shape of FDR file: 12
# Total input tryptic junction peptides: 4
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-0A132GA.txt
# Shape of FDR file: 49
# Total input tryptic junction peptides: 5
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-0213AGA.txt
# Shape of FDR file: 997
# Total input tryptic junction peptides: 20
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-0A13XGA.txt
# Shape of FDR file: 948
# Total input tryptic junction peptides: 21
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-0A53AGA.txt
# Shape of FDR file: 885
# Total input tryptic junction peptides: 17
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-0AN12GA.txt
# Shape of FDR file: 1875
# Total input tryptic junction peptides: 33
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-0AN3AGA.txt
# Shape of FDR file: 4019
# Total input tryptic junction peptides: 76
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-0AN3XGA.txt
# Shape of FDR file: 3490
# Total input tryptic junction peptides: 69
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-0A532GA.txt
# Shape of FDR file: 27
# Total input tryptic junction peptides: 3
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-0A112GA.txt
# Shape of FDR file: 1
# Total input tryptic junction peptides: 1
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-0A53XGA.txt
# Shape of FDR file: 437
# Total input tryptic junction peptides: 13
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-AO-A0JM/assign_conf_pooled_FDR_crux/tsearch-02112GA.txt
# Shape of FDR file: 1
# Total input tryptic junction peptides: 1
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-BH-A18V/assign_conf_pooled_FDR_crux/tsearch-J0A53XGA.txt
# Shape of FDR file: 842
# Total input tryptic junction peptides: 35
# Number of validated unique peptides: 1
# Validation Rate: 2.86 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-BH-A18V/assign_conf_pooled_FDR_crux/tsearch-J0A13AGA.txt
# Shape of FDR file: 8114
# Total input tryptic junction peptides: 288
# Number of validated unique peptides: 8
# Validation Rate: 2.78 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-BH-A18V/assign_conf_pooled_FDR_crux/tsearch-J0A51XGA.txt
# Shape of FDR file: 229
# Total input tryptic junction peptides: 11
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-BH-A18V/assign_conf_pooled_FDR_crux/tsearch-J0213XGA.txt
# Shape of FDR file: 1292
# Total input tryptic junction peptides: 43
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-BH-A18V/assign_conf_pooled_FDR_crux/tsearch-J0AN01GA.txt
# Shape of FDR file: 12154
# Total input tryptic junction peptides: 460
# Number of validated unique peptides: 9
# Validation Rate: 1.96 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-BH-A18V/assign_conf_pooled_FDR_crux/tsearch-J0A532GA.txt
# Shape of FDR file: 380
# Total input tryptic junction peptides: 19
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-BH-A18V/assign_conf_pooled_FDR_crux/tsearch-J0A11XGA.txt
# Shape of FDR file: 1517
# Total input tryptic junction peptides: 58
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-BH-A18V/assign_conf_pooled_FDR_crux/tsearch-J0253XGA.txt
# Shape of FDR file: 162
# Total input tryptic junction peptides: 9
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-BH-A18V/assign_conf_pooled_FDR_crux/tsearch-J0AN3AGA.txt
# Shape of FDR file: 25600
# Total input tryptic junction peptides: 922
# Number of validated unique peptides: 22
# Validation Rate: 2.39 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-BH-A18V/assign_conf_pooled_FDR_crux/tsearch-J0A51AGA.txt
# Shape of FDR file: 229
# Total input tryptic junction peptides: 11
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-BH-A18V/assign_conf_pooled_FDR_crux/tsearch-J0AN12GA.txt
# Shape of FDR file: 12405
# Total input tryptic junction peptides: 469
# Number of validated unique peptides: 11
# Validation Rate: 2.35 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-BH-A18V/assign_conf_pooled_FDR_crux/tsearch-J0A11AGA.txt
# Shape of FDR file: 1517
# Total input tryptic junction peptides: 58
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-BH-A18V/assign_conf_pooled_FDR_crux/tsearch-J0A101GA.txt
# Shape of FDR file: 1477
# Total input tryptic junction peptides: 56
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-BH-A18V/assign_conf_pooled_FDR_crux/tsearch-J0A501GA.txt
# Shape of FDR file: 215
# Total input tryptic junction peptides: 10
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-BH-A18V/assign_conf_pooled_FDR_crux/tsearch-J0211AGA.txt
# Shape of FDR file: 589
# Total input tryptic junction peptides: 18
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-BH-A18V/assign_conf_pooled_FDR_crux/tsearch-J0AN32GA.txt
# Shape of FDR file: 15852
# Total input tryptic junction peptides: 598
# Number of validated unique peptides: 12
# Validation Rate: 2.01 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-BH-A18V/assign_conf_pooled_FDR_crux/tsearch-J0A512GA.txt
# Shape of FDR file: 229
# Total input tryptic junction peptides: 11
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-BH-A18V/assign_conf_pooled_FDR_crux/tsearch-J0A112GA.txt
# Shape of FDR file: 1517
# Total input tryptic junction peptides: 58
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-BH-A18V/assign_conf_pooled_FDR_crux/tsearch-J0AN1AGA.txt
# Shape of FDR file: 12405
# Total input tryptic junction peptides: 469
# Number of validated unique peptides: 11
# Validation Rate: 2.35 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-BH-A18V/assign_conf_pooled_FDR_crux/tsearch-J02532GA.txt
# Shape of FDR file: 52
# Total input tryptic junction peptides: 6
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-BH-A18V/assign_conf_pooled_FDR_crux/tsearch-J0A13XGA.txt
# Shape of FDR file: 6026
# Total input tryptic junction peptides: 228
# Number of validated unique peptides: 4
# Validation Rate: 1.75 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-BH-A18V/assign_conf_pooled_FDR_crux/tsearch-J0253AGA.txt
# Shape of FDR file: 361
# Total input tryptic junction peptides: 13
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-BH-A18V/assign_conf_pooled_FDR_crux/tsearch-J0A132GA.txt
# Shape of FDR file: 2575
# Total input tryptic junction peptides: 101
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-BH-A18V/assign_conf_pooled_FDR_crux/tsearch-J0A53AGA.txt
# Shape of FDR file: 1655
# Total input tryptic junction peptides: 57
# Number of validated unique peptides: 1
# Validation Rate: 1.75 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-BH-A18V/assign_conf_pooled_FDR_crux/tsearch-J02101GA.txt
# Shape of FDR file: 575
# Total input tryptic junction peptides: 17
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-BH-A18V/assign_conf_pooled_FDR_crux/tsearch-J02112GA.txt
# Shape of FDR file: 589
# Total input tryptic junction peptides: 18
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-BH-A18V/assign_conf_pooled_FDR_crux/tsearch-J0213AGA.txt
# Shape of FDR file: 1760
# Total input tryptic junction peptides: 57
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-BH-A18V/assign_conf_pooled_FDR_crux/tsearch-J0AN3XGA.txt
# Shape of FDR file: 23151
# Total input tryptic junction peptides: 848
# Number of validated unique peptides: 18
# Validation Rate: 2.12 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-BH-A18V/assign_conf_pooled_FDR_crux/tsearch-J02132GA.txt
# Shape of FDR file: 794
# Total input tryptic junction peptides: 30
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-BH-A18V/assign_conf_pooled_FDR_crux/tsearch-J0211XGA.txt
# Shape of FDR file: 589
# Total input tryptic junction peptides: 18
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-BH-A18V/assign_conf_pooled_FDR_crux/tsearch-J0AN1XGA.txt
# Shape of FDR file: 12405
# Total input tryptic junction peptides: 469
# Number of validated unique peptides: 11
# Validation Rate: 2.35 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-BH-A18V/assign_conf_pooled_FDR_crux/tsearch-0211AGA.txt
# Shape of FDR file: 198
# Total input tryptic junction peptides: 3
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-BH-A18V/assign_conf_pooled_FDR_crux/tsearch-0211XGA.txt
# Shape of FDR file: 198
# Total input tryptic junction peptides: 3
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-BH-A18V/assign_conf_pooled_FDR_crux/tsearch-02532GA.txt
# Shape of FDR file: 38
# Total input tryptic junction peptides: 3
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-BH-A18V/assign_conf_pooled_FDR_crux/tsearch-0A101GA.txt
# Shape of FDR file: 344
# Total input tryptic junction peptides: 5
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-BH-A18V/assign_conf_pooled_FDR_crux/tsearch-0A512GA.txt
# Shape of FDR file: 143
# Total input tryptic junction peptides: 2
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-BH-A18V/assign_conf_pooled_FDR_crux/tsearch-0AN1AGA.txt
# Shape of FDR file: 925
# Total input tryptic junction peptides: 14
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-BH-A18V/assign_conf_pooled_FDR_crux/tsearch-0A13AGA.txt
# Shape of FDR file: 2803
# Total input tryptic junction peptides: 56
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-BH-A18V/assign_conf_pooled_FDR_crux/tsearch-0213XGA.txt
# Shape of FDR file: 1549
# Total input tryptic junction peptides: 34
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-BH-A18V/assign_conf_pooled_FDR_crux/tsearch-0A501GA.txt
# Shape of FDR file: 143
# Total input tryptic junction peptides: 2
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-BH-A18V/assign_conf_pooled_FDR_crux/tsearch-0A11AGA.txt
# Shape of FDR file: 344
# Total input tryptic junction peptides: 5
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-BH-A18V/assign_conf_pooled_FDR_crux/tsearch-0AN01GA.txt
# Shape of FDR file: 925
# Total input tryptic junction peptides: 14
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-BH-A18V/assign_conf_pooled_FDR_crux/tsearch-0AN1XGA.txt
# Shape of FDR file: 925
# Total input tryptic junction peptides: 14
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-BH-A18V/assign_conf_pooled_FDR_crux/tsearch-0AN32GA.txt
# Shape of FDR file: 1521
# Total input tryptic junction peptides: 27
# Number of validated unique peptides: 0
# Validation Rate: 0.0 percent
#
#
# ...
# Shape of FDR file: 15255
# Total input tryptic junction peptides: 9650
# Number of validated unique peptides: 183
# Validation Rate: 1.9 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-J02512GA.txt
# Shape of FDR file: 6029
# Total input tryptic junction peptides: 3723
# Number of validated unique peptides: 78
# Validation Rate: 2.1 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-J0AN32GA.txt
# Shape of FDR file: 84658
# Total input tryptic junction peptides: 56854
# Number of validated unique peptides: 844
# Validation Rate: 1.48 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-J0A512GA.txt
# Shape of FDR file: 23018
# Total input tryptic junction peptides: 14645
# Number of validated unique peptides: 314
# Validation Rate: 2.14 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-J0A112GA.txt
# Shape of FDR file: 46050
# Total input tryptic junction peptides: 30240
# Number of validated unique peptides: 533
# Validation Rate: 1.76 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-J0AN1AGA.txt
# Shape of FDR file: 77811
# Total input tryptic junction peptides: 52435
# Number of validated unique peptides: 771
# Validation Rate: 1.47 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-J02532GA.txt
# Shape of FDR file: 7393
# Total input tryptic junction peptides: 4540
# Number of validated unique peptides: 96
# Validation Rate: 2.11 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-J0A13XGA.txt
# Shape of FDR file: 59553
# Total input tryptic junction peptides: 38601
# Number of validated unique peptides: 705
# Validation Rate: 1.83 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-J0253AGA.txt
# Shape of FDR file: 10629
# Total input tryptic junction peptides: 6278
# Number of validated unique peptides: 158
# Validation Rate: 2.52 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-J0251AGA.txt
# Shape of FDR file: 6059
# Total input tryptic junction peptides: 3745
# Number of validated unique peptides: 78
# Validation Rate: 2.08 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-J02501GA.txt
# Shape of FDR file: 5769
# Total input tryptic junction peptides: 3585
# Number of validated unique peptides: 76
# Validation Rate: 2.12 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-J0A132GA.txt
# Shape of FDR file: 52119
# Total input tryptic junction peptides: 34045
# Number of validated unique peptides: 602
# Validation Rate: 1.77 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-J0A53AGA.txt
# Shape of FDR file: 34383
# Total input tryptic junction peptides: 21479
# Number of validated unique peptides: 467
# Validation Rate: 2.17 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-J02101GA.txt
# Shape of FDR file: 14654
# Total input tryptic junction peptides: 9315
# Number of validated unique peptides: 174
# Validation Rate: 1.87 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-J02112GA.txt
# Shape of FDR file: 15165
# Total input tryptic junction peptides: 9603
# Number of validated unique peptides: 183
# Validation Rate: 1.91 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-J0213AGA.txt
# Shape of FDR file: 23035
# Total input tryptic junction peptides: 14222
# Number of validated unique peptides: 298
# Validation Rate: 2.1 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-J0AN3XGA.txt
# Shape of FDR file: 92682
# Total input tryptic junction peptides: 61816
# Number of validated unique peptides: 952
# Validation Rate: 1.54 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-J02132GA.txt
# Shape of FDR file: 17850
# Total input tryptic junction peptides: 11254
# Number of validated unique peptides: 216
# Validation Rate: 1.92 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-J0211XGA.txt
# Shape of FDR file: 15255
# Total input tryptic junction peptides: 9650
# Number of validated unique peptides: 183
# Validation Rate: 1.9 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/OHSU/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-J0AN1XGA.txt
# Shape of FDR file: 77811
# Total input tryptic junction peptides: 52435
# Number of validated unique peptides: 771
# Validation Rate: 1.47 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-0211AGA.txt
# Shape of FDR file: 52976
# Total input tryptic junction peptides: 8397
# Number of validated unique peptides: 103
# Validation Rate: 1.23 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-0211XGA.txt
# Shape of FDR file: 52976
# Total input tryptic junction peptides: 8397
# Number of validated unique peptides: 103
# Validation Rate: 1.23 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-02532GA.txt
# Shape of FDR file: 38270
# Total input tryptic junction peptides: 6225
# Number of validated unique peptides: 74
# Validation Rate: 1.19 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-0A101GA.txt
# Shape of FDR file: 60973
# Total input tryptic junction peptides: 9724
# Number of validated unique peptides: 133
# Validation Rate: 1.37 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-0A512GA.txt
# Shape of FDR file: 53807
# Total input tryptic junction peptides: 8487
# Number of validated unique peptides: 113
# Validation Rate: 1.33 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-0AN1AGA.txt
# Shape of FDR file: 66335
# Total input tryptic junction peptides: 10639
# Number of validated unique peptides: 143
# Validation Rate: 1.34 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-0A13AGA.txt
# Shape of FDR file: 95178
# Total input tryptic junction peptides: 15269
# Number of validated unique peptides: 204
# Validation Rate: 1.34 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-0213XGA.txt
# Shape of FDR file: 80291
# Total input tryptic junction peptides: 12800
# Number of validated unique peptides: 158
# Validation Rate: 1.23 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-0A501GA.txt
# Shape of FDR file: 52205
# Total input tryptic junction peptides: 8224
# Number of validated unique peptides: 112
# Validation Rate: 1.36 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-0A11AGA.txt
# Shape of FDR file: 62795
# Total input tryptic junction peptides: 10034
# Number of validated unique peptides: 135
# Validation Rate: 1.35 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-0AN01GA.txt
# Shape of FDR file: 64510
# Total input tryptic junction peptides: 10327
# Number of validated unique peptides: 141
# Validation Rate: 1.37 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-0AN1XGA.txt
# Shape of FDR file: 66335
# Total input tryptic junction peptides: 10639
# Number of validated unique peptides: 143
# Validation Rate: 1.34 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-0AN32GA.txt
# Shape of FDR file: 78222
# Total input tryptic junction peptides: 12654
# Number of validated unique peptides: 172
# Validation Rate: 1.36 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-02101GA.txt
# Shape of FDR file: 51276
# Total input tryptic junction peptides: 8112
# Number of validated unique peptides: 101
# Validation Rate: 1.25 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-0A11XGA.txt
# Shape of FDR file: 62795
# Total input tryptic junction peptides: 10034
# Number of validated unique peptides: 135
# Validation Rate: 1.35 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-02132GA.txt
# Shape of FDR file: 63466
# Total input tryptic junction peptides: 10184
# Number of validated unique peptides: 128
# Validation Rate: 1.26 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-0251XGA.txt
# Shape of FDR file: 30756
# Total input tryptic junction peptides: 4977
# Number of validated unique peptides: 55
# Validation Rate: 1.11 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-0253AGA.txt
# Shape of FDR file: 53023
# Total input tryptic junction peptides: 8451
# Number of validated unique peptides: 98
# Validation Rate: 1.16 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-0253XGA.txt
# Shape of FDR file: 50756
# Total input tryptic junction peptides: 8135
# Number of validated unique peptides: 92
# Validation Rate: 1.13 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-0A132GA.txt
# Shape of FDR file: 74521
# Total input tryptic junction peptides: 12021
# Number of validated unique peptides: 164
# Validation Rate: 1.36 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-0213AGA.txt
# Shape of FDR file: 82759
# Total input tryptic junction peptides: 13173
# Number of validated unique peptides: 165
# Validation Rate: 1.25 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-0A13XGA.txt
# Shape of FDR file: 92599
# Total input tryptic junction peptides: 14876
# Number of validated unique peptides: 196
# Validation Rate: 1.32 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-0A53AGA.txt
# Shape of FDR file: 85149
# Total input tryptic junction peptides: 13528
# Number of validated unique peptides: 180
# Validation Rate: 1.33 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-0AN12GA.txt
# Shape of FDR file: 66208
# Total input tryptic junction peptides: 10610
# Number of validated unique peptides: 143
# Validation Rate: 1.35 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-0AN3AGA.txt
# Shape of FDR file: 98958
# Total input tryptic junction peptides: 15923
# Number of validated unique peptides: 212
# Validation Rate: 1.33 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-0A51XGA.txt
# Shape of FDR file: 53931
# Total input tryptic junction peptides: 8513
# Number of validated unique peptides: 113
# Validation Rate: 1.33 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-02501GA.txt
# Shape of FDR file: 29393
# Total input tryptic junction peptides: 4767
# Number of validated unique peptides: 54
# Validation Rate: 1.13 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-0AN3XGA.txt
# Shape of FDR file: 96367
# Total input tryptic junction peptides: 15528
# Number of validated unique peptides: 204
# Validation Rate: 1.31 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-0A532GA.txt
# Shape of FDR file: 65033
# Total input tryptic junction peptides: 10396
# Number of validated unique peptides: 140
# Validation Rate: 1.35 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-0A112GA.txt
# Shape of FDR file: 62668
# Total input tryptic junction peptides: 10006
# Number of validated unique peptides: 135
# Validation Rate: 1.35 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-0A53XGA.txt
# Shape of FDR file: 82606
# Total input tryptic junction peptides: 13147
# Number of validated unique peptides: 172
# Validation Rate: 1.31 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-0251AGA.txt
# Shape of FDR file: 30756
# Total input tryptic junction peptides: 4977
# Number of validated unique peptides: 55
# Validation Rate: 1.11 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-0A51AGA.txt
# Shape of FDR file: 53931
# Total input tryptic junction peptides: 8513
# Number of validated unique peptides: 113
# Validation Rate: 1.33 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-02512GA.txt
# Shape of FDR file: 30652
# Total input tryptic junction peptides: 4959
# Number of validated unique peptides: 55
# Validation Rate: 1.11 percent
#
#
# Reading /cluster/work/grlab/projects/projects2020_OHSU/proteomics_fixMerge_25012024/ETH/TCGA-24-2298/assign_conf_pooled_FDR_crux/tsearch-02112GA.txt
# Shape of FDR file: 52852
# Total input tryptic junction peptides: 8372
# Number of validated unique peptides: 103
# Validation Rate: 1.23 percent

# %%
## Get rates
if read_from_disk:
    compare = {'sample' : [], 
              'filter_' : [], 
              'pipeline': [], 
               'validation_rate':[]}
    
    for sample, experiments_ in samples_store_rates.items():
        for experiment, pipelines_ in experiments_.items():
            if ('OHSU' in pipelines_.keys()) and ('ETH' in pipelines_.keys()):
                for pipeline, rate in pipelines_.items():
                    compare['sample'].append(sample)
                    compare['filter_'].append(experiment)
                    compare['pipeline'].append( pipeline)
                    compare['validation_rate'].append(rate)

# %%
df1 = pd.DataFrame(compare)

# %%
## Compare peptides
if read_from_disk:
    compare = {'sample' : [], 
              'filter_' : [], 
              'pep_size_ohsu' : [], 
              'pep_size_eth' : [], 
              'pep_size_intersection' : [], 
              'pep_size_ohsu\eth' : [], 
              'pep_size_eth\ohsu' : []}

    for sample, experiments_ in samples_store_pep.items():
        for experiment, pipelines_ in experiments_.items():
            if ('OHSU' in pipelines_.keys()) and ('ETH' in pipelines_.keys()):
                compare['sample'].append(sample)
                compare['filter_'].append(experiment)
                compare['pep_size_ohsu'].append(len(pipelines_['OHSU']))
                compare['pep_size_eth'].append(len(pipelines_['ETH']))
                compare['pep_size_ohsu\eth'].append(len(pipelines_['OHSU'].difference(pipelines_['ETH'])))
                compare['pep_size_eth\ohsu'].append(len(pipelines_['ETH'].difference(pipelines_['OHSU'])))
                compare['pep_size_intersection'].append(len(pipelines_['ETH'].intersection(pipelines_['OHSU'])))

# %%
df2 = pd.DataFrame(compare)

# %%
## Get rates
if read_from_disk:
    compare = {'sample' : [], 
              'filter_' : [], 
              'pipeline': [], 
               'total':[]}
    
    for sample, experiments_ in samples_store_total.items():
        for experiment, pipelines_ in experiments_.items():
            if ('OHSU' in pipelines_.keys()) and ('ETH' in pipelines_.keys()):
                for pipeline, tot in pipelines_.items():
                    compare['sample'].append(sample)
                    compare['filter_'].append(experiment)
                    compare['pipeline'].append( pipeline)
                    compare['total'].append(tot)

# %%
df3 = pd.DataFrame(compare)

# %% [markdown]
# # Debug

# %%
criteria = '02501GA'
print(MS_strategy)

display(df1.loc[df1['filter_'] == criteria])
display(df2.loc[df2['filter_'] == criteria])
display(df3.loc[df3['filter_'] == criteria])
# Out:
# pool
#                            sample  filter_ pipeline  validation_rate
# 50   TCGA-C8-A12P-01A-11R-A115-07  02501GA     OHSU             0.00
# 51   TCGA-C8-A12P-01A-11R-A115-07  02501GA      ETH             0.00
# 290  TCGA-A2-A0SX-01A-12R-A084-07  02501GA     OHSU             0.00
# 291  TCGA-A2-A0SX-01A-12R-A084-07  02501GA      ETH             0.00
# 360  TCGA-25-1319-01A-01R-1565-13  02501GA     OHSU             2.78
# 361  TCGA-25-1319-01A-01R-1565-13  02501GA      ETH             1.63
# 430  TCGA-25-1313-01A-01R-1565-13  02501GA     OHSU             2.29
# 431  TCGA-25-1313-01A-01R-1565-13  02501GA      ETH             1.13
# 500  TCGA-61-2008-01A-02R-1568-13  02501GA     OHSU             2.37
# 501  TCGA-61-2008-01A-02R-1568-13  02501GA      ETH             1.70
# 570  TCGA-24-1431-01A-01R-1566-13  02501GA     OHSU             3.09
# 571  TCGA-24-1431-01A-01R-1566-13  02501GA      ETH             1.47
# 640  TCGA-24-2298-01A-01R-1569-13  02501GA     OHSU             2.12
# 641  TCGA-24-2298-01A-01R-1569-13  02501GA      ETH             1.13
#                            sample  filter_  pep_size_ohsu  pep_size_eth  \
# 25   TCGA-C8-A12P-01A-11R-A115-07  02501GA              0             0
# 145  TCGA-A2-A0SX-01A-12R-A084-07  02501GA              0             0
# 180  TCGA-25-1319-01A-01R-1565-13  02501GA             84            55
# 215  TCGA-25-1313-01A-01R-1565-13  02501GA             33            21
# 250  TCGA-61-2008-01A-02R-1568-13  02501GA             86            69
# 285  TCGA-24-1431-01A-01R-1566-13  02501GA             55            33
# 320  TCGA-24-2298-01A-01R-1569-13  02501GA             76            54
#
#      pep_size_intersection  pep_size_ohsu\eth  pep_size_eth\ohsu
# 25                       0                  0                  0
# 145                      0                  0                  0
# 180                     27                 57                 28
# 215                      8                 25                 13
# 250                     30                 56                 39
# 285                     15                 40                 18
# 320                     31                 45                 23
#                            sample  filter_ pipeline   total
# 50   TCGA-C8-A12P-01A-11R-A115-07  02501GA     OHSU     2.0
# 51   TCGA-C8-A12P-01A-11R-A115-07  02501GA      ETH     2.0
# 290  TCGA-A2-A0SX-01A-12R-A084-07  02501GA     OHSU     1.0
# 291  TCGA-A2-A0SX-01A-12R-A084-07  02501GA      ETH     NaN
# 360  TCGA-25-1319-01A-01R-1565-13  02501GA     OHSU  3021.0
# 361  TCGA-25-1319-01A-01R-1565-13  02501GA      ETH  3374.0
# 430  TCGA-25-1313-01A-01R-1565-13  02501GA     OHSU  1444.0
# 431  TCGA-25-1313-01A-01R-1565-13  02501GA      ETH  1855.0
# 500  TCGA-61-2008-01A-02R-1568-13  02501GA     OHSU  3636.0
# 501  TCGA-61-2008-01A-02R-1568-13  02501GA      ETH  4058.0
# 570  TCGA-24-1431-01A-01R-1566-13  02501GA     OHSU  1778.0
# 571  TCGA-24-1431-01A-01R-1566-13  02501GA      ETH  2247.0
# 640  TCGA-24-2298-01A-01R-1569-13  02501GA     OHSU  3585.0
# 641  TCGA-24-2298-01A-01R-1569-13  02501GA      ETH  4767.0

# %%
78/1309
# Out:
# 0.059587471352177235

# %%
50/1516
# Out:
# 0.032981530343007916

# %%
WHY IS THE JOINT TOTAL DIFFERENT FOR ETH AND OHSU.. HA script to pick up

# %% [markdown]
# # Plot: Results per experiment

# %%
# Choose plotting sample
sample = 'TCGA-25-1319-01A-01R-1565-13'
#sample =  'TCGA-AO-A0JM-01A-21R-A056-07'

# %%
if read_from_disk:
    df = pd.DataFrame(compare)
    display(df.head())
    print(df.shape)
else:
    df = None
# Out:
#                          sample  filter_  pep_size_ohsu  pep_size_eth  \
# 0  TCGA-C8-A12P-01A-11R-A115-07  0A53XGA              0             0
# 1  TCGA-C8-A12P-01A-11R-A115-07  0A13AGA              4             1
# 2  TCGA-C8-A12P-01A-11R-A115-07  0A51XGA              0             0
# 3  TCGA-C8-A12P-01A-11R-A115-07  0213XGA              1             1
# 4  TCGA-C8-A12P-01A-11R-A115-07  0AN01GA              6             2
#
#    pep_size_intersection  pep_size_ohsu\eth  pep_size_eth\ohsu
# 0                      0                  0                  0
# 1                      0                  4                  1
# 2                      0                  0                  0
# 3                      0                  1                  1
# 4                      2                  4                  0
# (330, 7)

# %%
def run_sample_plotting(sample_plot_dir, sample, df, MS_FDR, MS_strategy, save):
    order_file = os.path.join(sample_plot_dir[sample], f'{sample}_Barplot_sorting.tsv.gz')
    order_file = pd.read_csv(order_file, sep = '\t')
    display(order_file.head())
    print(order_file.shape)
    df_plot = order_file.merge(df, on = ['sample', 'filter_'], how = 'inner')
    df_plot = df_plot.fillna(0)
    print(df_plot.shape)
    df_plot = df_plot.sort_values('index')
    display(df_plot.head())
    # Plotting
    run_type = run_type_plot_dir[sample]

    back_ticks = df_plot['filter_background'] 
    front_ticks = df_plot['filter_foreground']

    serie_index = df_plot['index']
    serie_intersection = df_plot['pep_size_intersection']
    serie_eth = df_plot['pep_size_eth']
    print(serie_eth)
    serie_ohsu = df_plot['pep_size_ohsu']
    y_label = 'Number of MS-detected tryptic junction-peptides'

    name_plot = f'Barplot_ovelap_protein{MS_FDR}_{MS_strategy}'
    base_plot = sample
    plot_dir = sample_plot_dir[sample]

    plot_intersection_bars(back_ticks, front_ticks, ticks_fontsize, axislabels_fontsize, 
                              legend_fontsize, axes_fontsize, run_type, 
                               serie_index, serie_intersection, serie_eth, serie_ohsu,
                               y_label, save, plot_dir, base_plot, name_plot)
    return df_plot

# %%
# TMP CODE single sample
path_data = os.path.join(sample_plot_dir[sample], f'data{MS_FDR}_{MS_strategy}.tsv.gz')
print(path_data)
if df is not None:
    df.to_csv(path_data, sep = '\t', index = None)
else:
    df = pd.read_csv(path_data, sep = '\t')
df_plot = run_sample_plotting(sample_plot_dir, sample, df, MS_FDR, MS_strategy, save)
# Out:
# /cluster/work/grlab/projects/projects2020_OHSU/peptides_generation/CANCER_eth/commit_c4dd02c_conf2_Frame_cap0_runs/TCGA_Ovarian_374/filtering_samples/filters_19May_order_5ge_wAnnot_GPstar/plots/data_crema_joint.tsv.gz
#    Unnamed: 0                        sample  filter_  size_ohsu  size_eth  \
# 0           7  TCGA-25-1319-01A-01R-1565-13  02501GA      23972     20052
# 1          30  TCGA-25-1319-01A-01R-1565-13  02512GA      24766     20638
# 2          14  TCGA-25-1319-01A-01R-1565-13  0251AGA      24913     20683
# 3           8  TCGA-25-1319-01A-01R-1565-13  0251XGA      24913     20683
# 4          15  TCGA-25-1319-01A-01R-1565-13  02532GA      29573     24940
#
#    size_intersection  size_ohsu\eth  size_eth\ohsu  filter_foreground_target  \
# 0               8874          15098          11178                         0
# 1               9166          15600          11472                         0
# 2               9193          15720          11490                         0
# 3               9193          15720          11490                         0
# 4              11086          18487          13854                         0
#
#   filter_foreground_reads filter_foreground_samples  filter_background_reads  \
# 0                       2                         5                        0
# 1                       2                         5                        1
# 2                       2                         5                        1
# 3                       2                         5                        1
# 4                       2                         5                        3
#
#   filter_background_samples cohort motif  index filter_background  \
# 0                         1      G     A      0            (0, 1)
# 1                         2      G     A      1            (1, 2)
# 2                         A      G     A      2            (1, A)
# 3                         X      G     A      3            (1, X)
# 4                         2      G     A      4            (3, 2)
#
#   filter_foreground
# 0         (0, 2, 5)
# 1         (0, 2, 5)
# 2         (0, 2, 5)
# 3         (0, 2, 5)
# 4         (0, 2, 5)
# (35, 18)
# (35, 23)
#    Unnamed: 0                        sample  filter_  size_ohsu  size_eth  \
# 0           7  TCGA-25-1319-01A-01R-1565-13  02501GA      23972     20052
# 1          30  TCGA-25-1319-01A-01R-1565-13  02512GA      24766     20638
# 2          14  TCGA-25-1319-01A-01R-1565-13  0251AGA      24913     20683
# 3           8  TCGA-25-1319-01A-01R-1565-13  0251XGA      24913     20683
# 4          15  TCGA-25-1319-01A-01R-1565-13  02532GA      29573     24940
#
#    size_intersection  size_ohsu\eth  size_eth\ohsu  filter_foreground_target  \
# 0               8874          15098          11178                         0
# 1               9166          15600          11472                         0
# 2               9193          15720          11490                         0
# 3               9193          15720          11490                         0
# 4              11086          18487          13854                         0
#
#   filter_foreground_reads  ... cohort  motif index filter_background  \
# 0                       2  ...      G      A     0            (0, 1)
# 1                       2  ...      G      A     1            (1, 2)
# 2                       2  ...      G      A     2            (1, A)
# 3                       2  ...      G      A     3            (1, X)
# 4                       2  ...      G      A     4            (3, 2)
#
#   filter_foreground  pep_size_ohsu pep_size_eth pep_size_intersection  \
# 0         (0, 2, 5)             78           50                    27
# 1         (0, 2, 5)             81           50                    27
# 2         (0, 2, 5)             81           50                    27
# 3         (0, 2, 5)             81           50                    27
# 4         (0, 2, 5)             94           62                    34
#
#    pep_size_ohsu\eth  pep_size_eth\ohsu
# 0                 51                 23
# 1                 54                 23
# 2                 54                 23
# 3                 54                 23
# 4                 60                 28
#
# [5 rows x 23 columns]
# 0      50
# 1      50
# 2      50
# 3      50
# 4      62
# 5      81
# 6      84
# 7      82
# 8      82
# 9      82
# 10     82
# 11    100
# 12     88
# 13     88
# 14     88
# 15     88
# 16    129
# 17    132
# 18    106
# 19     98
# 20     98
# 21     98
# 22     98
# 23     99
# 24     99
# 25     99
# 26     99
# 27    137
# 28    141
# 29    116
# 30    117
# 31    148
# 32    152
# 33    150
# 34    154
# Name: pep_size_eth, dtype: int64
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [13], line 8
#       6 else:
#       7     df = pd.read_csv(path_data, sep = '\t')
# ----> 8 df_plot = run_sample_plotting(sample_plot_dir, sample, df, MS_FDR, MS_strategy, save)
#
# Cell In [12], line 28, in run_sample_plotting(sample_plot_dir, sample, df, MS_FDR, MS_strategy, save)
#      25 base_plot = sample
#      26 plot_dir = sample_plot_dir[sample]
# ---> 28 plot_intersection_bars(back_ticks, front_ticks, ticks_fontsize, axislabels_fontsize,
#      29                           legend_fontsize, axes_fontsize, run_type,
#      30                            serie_index, serie_intersection, serie_eth, serie_ohsu,
#      31                            y_label, save, plot_dir, base_plot, name_plot)
#      32 return df_plot
#
# NameError: name 'plot_intersection_bars' is not defined

# %%
# for sample in all_samples:
#     path_data = os.path.join(sample_plot_dir[sample], f'data{MS_FDR}_{MS_strategy}.tsv.gz')
#     print(path_data)
#     if df is not None:
#         df.to_csv(path_data, sep = '\t', index = None)
#     else:
#         df = pd.read_csv(path_data, sep = '\t')
#     run_sample_plotting(sample_plot_dir, sample, df, MS_FDR, MS_strategy, save)
