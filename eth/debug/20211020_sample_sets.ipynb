# %%
import glob 
import pandas as pd

# %%
glob.glob('/cluster/work/grlab/projects/projects2020_OHSU/sample_lists/*')
# Out:
# ['/cluster/work/grlab/projects/projects2020_OHSU/sample_lists/TCGA_All_Normals',
#  '/cluster/work/grlab/projects/projects2020_OHSU/sample_lists/GTEX_ETH',
#  '/cluster/work/grlab/projects/projects2020_OHSU/sample_lists/gdc_sample_sheet.2020-02-27.all.tsv',
#  '/cluster/work/grlab/projects/projects2020_OHSU/sample_lists/GTEX',
#  '/cluster/work/grlab/projects/projects2020_OHSU/sample_lists/TCGA_foreground',
#  '/cluster/work/grlab/projects/projects2020_OHSU/sample_lists/TCGA_matched_normals',
#  '/cluster/work/grlab/projects/projects2020_OHSU/sample_lists/GTEX_and_TCGA_normals']

# %% [markdown]
# # GTEX Core

# %%
gtex_oct = pd.read_csv('/cluster/work/grlab/projects/projects2020_OHSU/sample_lists/GTEX/GTEx_sample_IDs_10-2021_lib_graph_juliannelist', header = None)

# %%
gtex_eth_core = pd.read_csv('/cluster/work/grlab/projects/projects2020_OHSU/sample_lists/GTEX/GTEx_normal_samples_12-2020_noBrain_Testis.csv', header = None)

# %%
gtex_eth_core.head()
# Out:
#               0                        1            2
# 0  universal_id                  gtex_id  sample_type
# 1     SRR660824  GTEX-QMR6-1926-SM-32PL9         Lung
# 2     SRR606939  GTEX-POMQ-0326-SM-2I5FO        Heart
# 3    SRR2165473  GTEX-T5JC-0426-SM-5S2SL         Skin
# 4     SRR603858  GTEX-P4QR-1026-SM-2I5GP         Lung

# %%
core_samples = []
non_core_samples = []

for run_sample in gtex_oct[0]:
    if run_sample.replace('all', '') in gtex_eth_core[0].to_list():
        core_samples.append(run_sample)
    else:
        non_core_samples.append(run_sample)

# %%
len(gtex_eth_core)
# Out:
# 7944

# %%
len(core_samples)
# Out:
# 7876

# %%
len(non_core_samples)
# Out:
# 1601

# %%
non_core_samples
# Out:
# ['SRR1421093all',
#  'SRR1394713all',
#  'SRR1348339all',
#  'SRR1375907all',
#  'SRR1440699all',
#  'SRR1440517all',
#  'SRR1440119all',
#  'SRR1434250all',
#  'SRR1456950all',
#  'SRR1458134all',
#  'SRR659472all',
#  'SRR1367870all',
#  'SRR1401276all',
#  'SRR1317323all',
#  'SRR1429579all',
#  'SRR1480479all',
#  'SRR1349013all',
#  'SRR659484all',
#  'SRR1444264all',
#  'SRR1320093all',
#  'SRR1467212all',
#  'SRR1414595all',
#  'SRR604528all',
#  'SRR614563all',
#  'SRR659780all',
#  'SRR1443201all',
#  'SRR1400997all',
#  'SRR1325332all',
#  'SRR1376270all',
#  'SRR1319158all',
#  'SRR602927all',
#  'SRR1335707all',
#  'SRR821549all',
#  'SRR812912all',
#  'SRR1441200all',
#  'SRR1403222all',
#  'SRR1472079all',
#  'SRR1360128all',
#  'SRR1361757all',
#  'SRR1074164all',
#  'SRR1349056all',
#  'SRR1387945all',
#  'SRR1098519all',
#  'SRR1470902all',
#  'SRR1400269all',
#  'SRR1486304all',
#  'SRR1313426all',
#  'SRR1474466all',
#  'SRR1405182all',
#  'SRR601500all',
# ...

# %%
GTEX_final_core = pd.DataFrame({'core_sample':core_samples})

# %%
GTEX_final_core.to_csv('/cluster/work/grlab/projects/projects2020_OHSU/sample_lists/GTEX/GTEx_sample_IDs_10-2021_lib_graph_juliannelist_noBrain_noTestis', header = None, index = None)

# %% [markdown]
# # GTEX

# %%
glob.glob('/cluster/work/grlab/projects/projects2020_OHSU/sample_lists/GTEX/*')
# Out:
# ['/cluster/work/grlab/projects/projects2020_OHSU/sample_lists/GTEX/notfound_matrix_spot_origin_notRNAseq',
#  '/cluster/work/grlab/projects/projects2020_OHSU/sample_lists/GTEX/GTEx_sample_IDs_03-2021_correct_missing40_julianne.csv',
#  '/cluster/work/grlab/projects/projects2020_OHSU/sample_lists/GTEX/GTEx_sample_IDs_03-2021_correct_missing40_julianne_suffix.csv',
#  '/cluster/work/grlab/projects/projects2020_OHSU/sample_lists/GTEX/GTEx_sample_IDs_10-2021_lib_graph_juliannelist',
#  '/cluster/work/grlab/projects/projects2020_OHSU/sample_lists/GTEX/tmp',
#  '/cluster/work/grlab/projects/projects2020_OHSU/sample_lists/GTEX/notfound_matrix_spot_origin',
#  '/cluster/work/grlab/projects/projects2020_OHSU/sample_lists/GTEX/GTEx_sample_IDs_08-2021.csv',
#  '/cluster/work/grlab/projects/projects2020_OHSU/sample_lists/GTEX/not_found_back_matrix']

# %%
gtex_oct = pd.read_csv('/cluster/work/grlab/projects/projects2020_OHSU/sample_lists/GTEX/GTEx_sample_IDs_10-2021_lib_graph_juliannelist', header = None)

# %%
gtex_oct.head()
# Out:
#                0
# 0   SRR661397all
# 1  SRR1418968all
# 2  SRR1421093all
# 3  SRR1356120all
# 4  SRR1378903all

# %% [markdown]
# # Matched Normals

# %%
glob.glob('/cluster/work/grlab/projects/projects2020_OHSU/sample_lists/TCGA_matched_normals/*')
# Out:
# ['/cluster/work/grlab/projects/projects2020_OHSU/sample_lists/TCGA_matched_normals/gdc_sample_sheet.2020-02-27_BRCA_normals.all.tsv',
#  '/cluster/work/grlab/projects/projects2020_OHSU/sample_lists/TCGA_matched_normals/list_spladder_TCGA_matched_normals']

# %%
matched_TCGA_spladder = pd.read_csv('/cluster/work/grlab/projects/projects2020_OHSU/sample_lists/TCGA_matched_normals/list_spladder_TCGA_matched_normals',
                                  header = None)

# %%
matched_TCGA_spladder.head()
# Out:
#                       0
# 0  TCGA-A7-A0CE-11A.all
# 1  TCGA-A7-A0CH-11A.all
# 2  TCGA-A7-A0D9-11A.all
# 3  TCGA-A7-A0DB-11A.all
# 4  TCGA-A7-A0DC-11A.all

# %%
glob.glob('/cluster/work/grlab/projects/projects2020_OHSU/sample_lists/TCGA_matched_normals/*')

# %%
lib_all_normals = pd.read_csv('/cluster/work/grlab/projects/projects2020_OHSU/peptides_generation/v2_libsizes_conf2_annotFrame_cap1000_runs_pya0.17.1_KEEP/TCGA_All_Normals/cohort_mutNone/TCGA_All_Normals_coding_libsize75.tsv', sep = '\t')

# %%
lib_all_normals.head()
# Out:
#              sample  libsize_75percent
# 0  TCGA06067511Aall           245812.0
# 1  TCGA06067811Aall           235831.0
# 2  TCGA06068011Aall           282101.0
# 3  TCGA06068111Aall           258851.0
# 4  TCGA06AABW11Aall           213404.0

# %%
for idx, matched in matched_TCGA_spladder.iterrows():
    if not matched[0].replace('.', '').replace('-', '') in lib_all_normals['sample'].to_list():
        print('{} missing'.format(matched))

# %% [markdown]
# Seems that all matched have been processed correctly
# Differentialte matched normals origin
# -> Actually not Needed! Because we are looking at the BRCA matched normals only

# %% [markdown]
# # All Normals

# %%
matched_TCGA_spladder[0].to_list()
# Out:
# ['TCGA-A7-A0CE-11A.all',
#  'TCGA-A7-A0CH-11A.all',
#  'TCGA-A7-A0D9-11A.all',
#  'TCGA-A7-A0DB-11A.all',
#  'TCGA-A7-A0DC-11A.all',
#  'TCGA-A7-A13E-11A.all',
#  'TCGA-A7-A13F-11A.all',
#  'TCGA-A7-A13G-11A.all',
#  'TCGA-AC-A23H-11A.all',
#  'TCGA-AC-A2FB-11A.all',
#  'TCGA-AC-A2FF-11A.all',
#  'TCGA-AC-A2FM-11B.all',
#  'TCGA-BH-A0AU-11A.all',
#  'TCGA-BH-A0AY-11A.all',
#  'TCGA-BH-A0AZ-11A.all',
#  'TCGA-BH-A0B3-11B.all',
#  'TCGA-BH-A0B5-11A.all',
#  'TCGA-BH-A0B7-11A.all',
#  'TCGA-BH-A0B8-11A.all',
#  'TCGA-BH-A0BA-11A.all',
#  'TCGA-BH-A0BC-11A.all',
#  'TCGA-BH-A0BJ-11A.all',
#  'TCGA-BH-A0BM-11A.all',
#  'TCGA-BH-A0BQ-11A.all',
#  'TCGA-BH-A0BS-11A.all',
#  'TCGA-BH-A0BT-11A.all',
#  'TCGA-BH-A0BV-11A.all',
#  'TCGA-BH-A0BW-11A.all',
#  'TCGA-BH-A0BZ-11A.all',
#  'TCGA-BH-A0C0-11A.all',
#  'TCGA-BH-A0C3-11A.all',
#  'TCGA-BH-A0DD-11A.all',
#  'TCGA-BH-A0DG-11A.all',
#  'TCGA-BH-A0DH-11A.all',
#  'TCGA-BH-A0DK-11A.all',
#  'TCGA-BH-A0DL-11A.all',
#  'TCGA-BH-A0DO-11A.all',
# ...

# %%
lib_all_normals = pd.read_csv('/cluster/work/grlab/projects/projects2020_OHSU/peptides_generation/v2_libsizes_conf2_annotFrame_cap1000_runs_pya0.17.1_KEEP/TCGA_All_Normals/cohort_mutNone/TCGA_All_Normals_coding_libsize75.tsv', sep = '\t')

# %%
glob.glob('/cluster/work/grlab/projects/projects2020_OHSU/sample_lists/TCGA_All_Normals/*')
# Out:
# ['/cluster/work/grlab/projects/projects2020_OHSU/sample_lists/TCGA_All_Normals/TCGA_normal_sample_IDs_03-2021_julianne.csv',
#  '/cluster/work/grlab/projects/projects2020_OHSU/sample_lists/TCGA_All_Normals/TCGA_normal_sample_ID_index_12-2020.csv',
#  '/cluster/work/grlab/projects/projects2020_OHSU/sample_lists/TCGA_All_Normals/sample_full_All_Normals.tsv']

# %%
all_normals_spladder = pd.read_csv('/cluster/work/grlab/projects/projects2020_OHSU/sample_lists/TCGA_All_Normals/sample_full_All_Normals.tsv', header = None)

# %%
all_normals_spladder.head()
# Out:
#                       0
# 0  TCGA-06-0675-11A.all
# 1  TCGA-06-0678-11A.all
# 2  TCGA-06-0680-11A.all
# 3  TCGA-06-0681-11A.all
# 4  TCGA-06-AABW-11A.all

# %%
for idx, normal in all_normals_spladder.iterrows():
    if  not normal[0].replace('.', '').replace('-', '') in lib_all_normals['sample'].to_list():
        print('{} missing'.format(normal))

# %% [markdown]
# seems that all the normals ahave been processed correctly
